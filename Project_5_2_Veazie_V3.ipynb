# %% [markdown]
# <a href="https://colab.research.google.com/github/sveazie/GitHub-Collaboration-Practice/blob/main/Project_5_2_Veazie_V3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [Computational Social Science]
# ## 5-5 Deep Learning - Solutions

# %% [markdown]
# In the following cell are the packages that you will need to complete this notebook. Run this line of code to make sure that everything is installed properly.

# %%
#import packages for deep learning
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
# from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import RMSprop

# %% [markdown]
# # Huggingface

# %% [markdown]
# Objectives:
# - Explore tasks and data available in Huggingface transformers
# - Choose an appropriate language task
# - Implement a transformer on local data
#
# 20 minutes

# %% [markdown]
# In reality, these models  require significant data and computational power, which can exceed the resources available to the analyst. We can circumvent this problem by using pre-trained models. Like a pre-trained embedding model, pre-trained models are trained on a large dataset. While this may not perfectly align with the data or task you have, it can help create a more robust system that can be fine-tuned to your data and goals.
#
# [Huggingface](https://huggingface.co/models) is a set of pretrained models from a variety of datasets and sources with an easy-to-use interface. In this section, we will explore the use of the Huggingface library to streamline language task processing.

# %%
#install the transformers library
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)

# %% [markdown]
# # Large Language Model
# We can use a large language model such as GPT-2 or GPT-Neo with the Hugging Face Transformers library. In this example, we will generate text using the GPT-2 model with the Hugging Face Transformers library. This example will use the code below to produce five different continuations of the provided input text.
#
# We will use pipeline function. The pipeline function is a simple way to create a model with its associated preprocessing and postprocessing steps.  It's a high-level function provided by the Hugging Face Transformers library that makes it easy to load a pre-trained model with its associated tokenizer and use it for various tasks like text generation, sentiment analysis, and more. Using the pipeline function is not strictly necessary, but it does simplify the code by abstracting away several underlying details.

# %%
from transformers import pipeline, set_seed
# Here, 'text-generation' tells the pipeline to create a text generation model, and model='gpt2'
# specifies that you want to use the GPT-2 model for this task.
generator = pipeline('text-generation', model='gpt2')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
set_seed(100)
input_text = "We practiced using supervised and unsupervised tools to analyze whether the content of Congress members tweets as well as other information about their gender, birthday, state, and date they joined Congress can be used to predict their political party."
# specifying the maximum length of the output, and the number of different sequences you want
output = generator(input_text, max_length=300, num_return_sequences=5)
for result in output:
    print(result['generated_text'])
    print("----")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# We practiced using supervised and unsupervised tools to analyze whether the content of Congress members tweets as well as other information about their gender, birthday, state, and date they joined Congress can be used to predict their political party. We then asked participants to vote whether they considered other candidates or parties representative of the United States, and reported on the voting of their voting decision within the context of voting on specific national candidate, party, or party.
#
# This was the initial study. We also wanted to test out how representative Democrats or Republicans in the 2016 election could be of interest to voters. Because the Electoral College is a democratic system, there is some chance that members could benefit from representation from only three parties. We also wanted to assess if the influence of each party on the outcome of the 2016 election is large enough to influence the voting outcome of other candidates and parties in the election. Therefore, we wanted to perform an open-ended question-mark form to be available to each participant. After selecting a question, we then asked participants to rate their level of significance for "representation in federal government." We also wanted to see if there was a relationship between representation in the public and voter preferences. Our final results set us up for a future research challenge aimed at building on this important feature of analysis that is currently a requirement of political science research.
#
# METHODS
#
# Sample
#
# The analyses presented here are from a small national sample. The data are weighted by individual country-specific characteristics
# ----
# We practiced using supervised and unsupervised tools to analyze whether the content of Congress members tweets as well as other information about their gender, birthday, state, and date they joined Congress can be used to predict their political party. The data showed significant partisan gaps in tweets from 2016. For example, from 2014 until 2016, Democrats received more tweets from Democrats than Republicans, while members of the left only received less tweets than Republicans. And this trend also differed across partisans. Those partisan gaps for the five years following the 2016 presidential campaign did not change, but if the data from January through April were captured as they would in January of last year, Democrats received more tweets from Democrats than Republicans even though Democrats only got more tweets from Republicans.
#
# Despite these stark similarities and differences, Congress can still run afoul of laws and policy changes that would restrict certain partisan speech. For example, the "don't ask, don't tell" rule, enacted in 2010 to limit the potential threat of "substance abuse" and "abuse or misrepresentation of personal information" by Congress, allows members of Congress to use their first name to respond to a question at the Congressional Budget Office regarding a budget. In effect, a member of Congress and a constituent may not respond directly to a question from the Office of Government Ethics within 30 days if they take a policy position that the member is not an expert in the subject matter of the request. Instead, they may respond in the form of an answer. Another rule
# ----
# We practiced using supervised and unsupervised tools to analyze whether the content of Congress members tweets as well as other information about their gender, birthday, state, and date they joined Congress can be used to predict their political party. Using such tools, the Federalist Papers reveal what is often left out of the public record.
#
# What Are Congressional Statutes?
#
# Congress is composed of 60 states, three of which are the Senate and five of which are its House. In these states, "member of Congress" can be any member of Congress or any other designated official. This means that although members of Congress may attend events, those who don't have a residence in the federal government (the United States) may attend, or those who hold a "person on a government staff position" (an employee position) may attend. Under federal law, these members in the United States would not be recognized as members of Congress based on their political affiliations, but rather as persons that met the terms "one" and "two."
#
# According to the Federalist Papers, when a member of Congress is considered to be a member of the House of Representatives, this designation would be derived from the President's term of office (this definition will be more precise in future editions). Therefore, Congress' definition of its members is not limited to only those elected from member committees. Members of Congress may also be elected to congress by simple majority votes. As in the United States, only members of Congress are
# ----
# We practiced using supervised and unsupervised tools to analyze whether the content of Congress members tweets as well as other information about their gender, birthday, state, and date they joined Congress can be used to predict their political party.
#
# We also evaluated the impact of political party affiliations on political sentiment in the current Congress, in which we found stronger partisan loyalty among women, including a significant correlation between party affiliation and voter behavior.
#
# Our research supports the concept that we use this approach to predict election outcomes using political party affiliation as data sources. We found, in particular, evidence for more substantive results for female voters in current Congress (Fig. 2), and also for broader results for men based on party affiliation (Fig. 3). To test whether these results may reflect partisan loyalty, we divided the results of this study into three stages based on partisan loyalty, gender, age, and gender preference (Figs. S1 and S2). After this stage, we performed the experiment for which we first modeled participants' voting behavior over the next year.
#
# In our first experiment, we found associations between party affiliations and voters' political behavior (Fig. 3). This suggests that there may exist associations that exist in social relationships but cannot account for demographic variation. The study authors also found significant correlations between partisanship and the number of members of Congress (for "top 5" political party members), indicating that political party affiliation does not play an important role for voting behavior. Further, it
# ----
# We practiced using supervised and unsupervised tools to analyze whether the content of Congress members tweets as well as other information about their gender, birthday, state, and date they joined Congress can be used to predict their political party. We found that these analyses resulted in more than half of all tweets from Democratic or Republican members of Congress that were highly correlated with social rank. The findings suggest that Republicans and Democrats generally are more likely to tweet as a share of the public than do Democrats or Republicans.
#
# Because the analysis did not involve respondents' own or others' identities, it does not require respondents to be members of a specific political party. Only those who had at least one political affiliation on their social media accounts will be matched with our results, not those who are randomly selected by demographic and social background variables like race, ethnicity, and age.
#
# We expect that the relationship between Twitter data for Congress Members and Trump tweets will provide greater predictive power for the future, because of the greater accuracy of our analysis and because the public may have confidence in predicting their political party when their tweets are publicly available.
#
# REMEDY: Do you think Twitter has an effect on Congress?
#
# DETON: I do, but that is what I will add. I don't think Twitter has an effect on Congress because social media allows people to choose for themselves different views from the ones people typically see. But I do think it does have a negative impact because it forces people to think harder about
# ----

# %% [markdown]
# # Challenge
# We can experiment changing different hyper parameters in the model above. Experiment by specifying different values for *temperature* parameter in generator function.
# <br>
# Temperature regulates the unpredictability of a language model's output. With higher temperature settings, outputs become more creative and less predictable as it amplifies the likelihood of less probable tokens while reducing that for more probable ones. A temperature value that is higher, such as 1.7, encourages the generation of text that is more varied and imaginative. Conversely, a lower temperature value, like 0.7, steers the output towards more concentrated and predictable text.

# %%
output = generator(input_text, max_length=300, num_return_sequences=5, temperature = 0.7)
for result in output:
    print(result['generated_text'])
    print("----")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# We practiced using supervised and unsupervised tools to analyze whether the content of Congress members tweets as well as other information about their gender, birthday, state, and date they joined Congress can be used to predict their political party. While this study did not directly examine whether the accuracy of the congressional tweets would be affected by their gender or political party, the results suggested that the accuracy of any tweets that were sent by women would be related to their political party affiliation.
#
# "This is an exciting development and one that would have interesting implications for the ability to predict the future political behavior of congressmen and women. The findings suggest that the ability of women to predict and manipulate the political behavior of their elected officials is a good idea. The ability of women to influence the political behavior of congressmen and women supporters is a key to understanding the influence of women on political outcomes," said David W. Misko, an associate professor of sociology and political science at the University of Illinois and assistant professor of political science at the University of Illinois at Chicago.
#
# The research was supported by grants from the National Science Foundation, the National Science Foundation, the National Science Foundation, the National Science Foundation, and the National Science Foundation, and by the National Science Foundation.
#
# This research was funded by the National Science Foundation, the National Science Foundation, the National Science Foundation, the National Science Foundation, the National Science Foundation, the National Science Foundation, the National Science Foundation, the National Science Foundation, the National
# ----
# We practiced using supervised and unsupervised tools to analyze whether the content of Congress members tweets as well as other information about their gender, birthday, state, and date they joined Congress can be used to predict their political party. The first step was to determine the impact of congressional Twitter users on their political opinions. In addition to the partisan vote, we also looked to data on political behavior in the Senate. We found that Republicans appear to retweet more tweets from the public than Democrats, and that partisan tweets from the public are associated with a higher likelihood of being retweeted by more people.
#
# We then performed the same analysis using another dataset from a different type of research (an earlier study [18]) using data from the National Science Foundation. This time, we focused on the public's views on the issue of nuclear weapons. We found that the public's views on nuclear weapons are associated with a higher probability of being retweeted by more people. In addition, the public's views on the issue of nuclear weapons were also associated with a higher likelihood of being retweeted by more people.
#
# In addition to the public's views on the issue of nuclear weapons, we also analyzed a series of social media trends from the same data. We found that tweets from the public were the most likely to be retweeted by more people than tweets from the public. In addition, tweets from the public were reported more often than tweets from the public. The first line of analysis, along with the second,
# ----
# We practiced using supervised and unsupervised tools to analyze whether the content of Congress members tweets as well as other information about their gender, birthday, state, and date they joined Congress can be used to predict their political party.
#
# In other words, we asked whether members of Congress use certain social media messages to influence their behavior. We also asked whether they use social media messages to influence their voting behavior. Finally, we asked if they use social media messages to influence their voting decision. We also asked whether they use social media messages to influence their voting choice.
#
# The results show a clear trend in women's voting behavior. Women's voting behavior increased in the first half of 2013, from 37 percent of respondents to 29 percent. That was down from 40 percent in the first half of 2013. In addition, women's voting behavior increased at a much faster rate than men's during the same time period, from 4.5 percent to 3.7 percent.
#
# The researchers estimate that women's voting behavior increased by 4.7 percent in 2013. The average increase in voting behavior during the first half of 2013 (from 20.6 percent to 41.7 percent) was up 7.6 percent.
#
# However, the study authors note that women's voting behaviors did not increase in the first half of 2013.
#
# "We expected that women's voting behavior would increase in the first half of 2013. However, the data are not consistent with this prediction," says J.
# ----
# We practiced using supervised and unsupervised tools to analyze whether the content of Congress members tweets as well as other information about their gender, birthday, state, and date they joined Congress can be used to predict their political party.
#
# The findings were published online this week in the journal Political Science.
#
# The study used a standard statistical analysis tool that examines the relationship between tweets from individuals and political parties. The research team used a sample of over 4,000 tweets from more than 3.6 million tweets. The researchers found that tweets from people who were male and women who were female would predict whether the tweets were associated with or not with the party of their choice, but not with the party of their party of choice.
#
# "Our findings suggest that the gender of tweets from people who are not Republican or Democrat might predict who they will vote for in 2016," said lead study author Dr. David H. Miller, an assistant professor of political science at George Mason University in Virginia.
#
# The study was funded by the National Science Foundation, the National Science Foundation and the National Science Foundation's National Science Foundation's Office of Research, Research and Analysis. Authors include Jennifer Sexton, a postdoctoral fellow at the University of Colorado-Pueblo, and David A. Miller, a doctoral student at the University of California at Berkeley. The research was supported by the National Science Foundation, National Science Foundation, and the National Science Foundation.
#
# Miller and Miller are the co-authors
# ----
# We practiced using supervised and unsupervised tools to analyze whether the content of Congress members tweets as well as other information about their gender, birthday, state, and date they joined Congress can be used to predict their political party.
#
# The authors note that the data suggest that, in general, women can be more likely to be elected, and vice versa, and that women are more likely to serve in office and to lead committees.
#
# "A lack of access to information about people's gender is a major cause of gender bias," said Daniela G. Fessler, a professor of law at Harvard Law School and the co-author of "Women in the House: Why Women Are More Likely to Be Elected, Vice-Presidents, and Congressors." "There is a growing body of research showing that women are more likely to be involved in the political process than men. This suggests that it is not the only factor influencing the performance of women in congress."
#
# Fessler and her colleagues used a multivariate analysis of congressional tweets to estimate the number of women in the House and Senate. They found that of 16 people who responded, 34 were women, compared to 15 who were men. The disparity in tweets was most pronounced among women, with a similar proportion of women tweeting as women, with a gender gap of 1.23 percent (compared to 1.23 percent for men).
#
# They found that in addition to women, men were also more likely to tweet
# ----

# %% [markdown]
# We used GPT2 to generate text above because it is free and runs relatively faster to be able to demonstrate in a classroom setting.  Sometimes, using a larger and more powerful model such as GPT-3 instead of GPT-2 can improve the quality of the generated text. Larger models often capture nuances and subtleties better. However, larger models often take longer time to run and some of the newest models are only available through a paid API.

# %% [markdown]
# ## Challenge
#
# Let's practice with another task from [huggingface](https://huggingface.co/docs/transformers/task_summary).
#
# Let's say we want to check our data for grammatical correctness. We will use the CoLA model ("textattack/distilbert-base-uncased-CoLA") in the Text Classification pipeline ('text-classification') What is the grammatical correctness of each of the first 15 entries in the cfpb dataset?

# %%
#solution
classifier = pipeline("text-classification", model = "textattack/distilbert-base-uncased-CoLA")
classifier("I went to the bus.")
# Out:
# [{'label': 'LABEL_1', 'score': 0.9881684184074402}]

# %% [markdown]
# There are thousands of models on huggingface that can be used for a variety of language tasks. This can be a great way to use the models already available to increase our modeling power.

# %% [markdown]
# # Next Steps
#
# This lab has introduced Colab as a way to use GPUs to speed up processing power and explored further applications of deep learning to natural language processing.
#
# In practice, using deep learning for computational social science requires building on the foundational concepts covered in this notebook to implement models with more complicated data and architecture. However, there are many strategies can help you navigate the model ecosystem, some of which we will discuss here:
#
# 1. Documentation (and other resources like tutorials) is a goldmine of information for implementing particular algorithms and completing specific tasks. This is one reason why reading and translating code written by others is a key skill.
#
# 2. Debugging and interpreting error messages, as well as leveraging online resources in order to resolve them, is another key concept. Resources like documentation and Stack Overflow help solve common errors and get code working faster.
#
# 3. Computational resources are important for running complex models. Google Colab has access to GPUs, but does have limitations for large and extended jobs. In those cases, options are paid services such as Google Colab Pro or on-campus [resources](https://docs-research-it.berkeley.edu/services/high-performance-computing/overview/).
#
# 4. Further resources:
#   - Deep Learning with Python (Francois Chollet)
#   - [Huggingface course](https://huggingface.co/course/chapter1/1)
#   - [Tensorflow](https://www.tensorflow.org/tutorials)
